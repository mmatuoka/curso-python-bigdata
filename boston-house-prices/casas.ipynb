# %%
import pandas as pd
import numpy as np

columns = [
    'CRIM'   ,
    'ZN'     ,
    'INDUS'  ,
    'CHAS'   ,
    'NOX'    ,
    'RM'     ,
    'AGE'    ,
    'DIS'   ,
    'RAD'    ,
    'TAX'    ,
    'PTRATIO',
    'B'      ,
    'LSTAT'  ,
    'MEDV'  ,
]
#boston = pd.read_csv('housing.csv', sep='  ', names=columns, header=None)
data = []

with open('housing.csv', 'r') as f:
    for line in f.readlines():
        data.append([float(x) for x in line.split(' ') if x != ''])
        
boston = pd.DataFrame(data, columns=columns)

boston
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX             RM     AGE     DIS    RAD  \
# 0     0.00632  18.0   2.31   0.0  0.538         6.5750   65.20  4.0900    1.0
# 1     0.02731   0.0   7.07   0.0  0.469         6.4210   78.90  4.9671    2.0
# 2     0.02729   0.0   7.07   0.0  0.469         7.1850   61.10  4.9671    2.0
# 3     0.03237   0.0   2.18   0.0  0.458         6.9980   45.80  6.0622    3.0
# 4     0.06905   0.0   2.18   0.0  0.458         7.1470   54.20  6.0622    3.0
# 5     0.02985   0.0   2.18   0.0  0.458         6.4300   58.70  6.0622    3.0
# 6     0.08829  12.5   7.87   0.0  0.524         6.0120   66.60  5.5605    5.0
# 7     0.14455  12.5   7.87   0.0  0.524         6.1720   96.10  5.9505    5.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.6310 100.00  6.0821  5.0000  311.0
# 9     0.17004  12.5   7.87   0.0  0.524         6.0040   85.90  6.5921    5.0
# 10    0.22489  12.5   7.87   0.0  0.524         6.3770   94.30  6.3467    5.0
# ...

# %%
data = []

with open()


boston = boston.fillna(0)
boston
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX             RM     AGE     DIS    RAD  \
# 0     0.00632  18.0   2.31   0.0  0.538         6.5750   65.20  4.0900    1.0
# 1     0.02731   0.0   7.07   0.0  0.469         6.4210   78.90  4.9671    2.0
# 2     0.02729   0.0   7.07   0.0  0.469         7.1850   61.10  4.9671    2.0
# 3     0.03237   0.0   2.18   0.0  0.458         6.9980   45.80  6.0622    3.0
# 4     0.06905   0.0   2.18   0.0  0.458         7.1470   54.20  6.0622    3.0
# 5     0.02985   0.0   2.18   0.0  0.458         6.4300   58.70  6.0622    3.0
# 6     0.08829  12.5   7.87   0.0  0.524         6.0120   66.60  5.5605    5.0
# 7     0.14455  12.5   7.87   0.0  0.524         6.1720   96.10  5.9505    5.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.6310 100.00  6.0821  5.0000  311.0
# 9     0.17004  12.5   7.87   0.0  0.524         6.0040   85.90  6.5921    5.0
# 10    0.22489  12.5   7.87   0.0  0.524         6.3770   94.30  6.3467    5.0
# ...

# %%
#boston['AGE'].map(lambda x:float(x)).dtype

casas_intervalo = boston[(boston['AGE'] > 30) & (boston['AGE'] < 50)]
casas_intervalo
# Out:
#         CRIM     ZN  INDUS  CHAS    NOX     RM   AGE      DIS   RAD    TAX  \
# 3    0.03237    0.0   2.18   0.0  0.458  6.998  45.8   6.0622   3.0  222.0
# 12   0.09378   12.5   7.87   0.0  0.524  5.889  39.0   5.4509   5.0  311.0
# 18   0.80271    0.0   8.14   0.0  0.538  5.456  36.6   3.7965   4.0  307.0
# 37   0.08014    0.0   5.96   0.0  0.499  5.850  41.5   3.9342   5.0  279.0
# 38   0.17505    0.0   5.96   0.0  0.499  5.966  30.2   3.8473   5.0  279.0
# 44   0.12269    0.0   6.91   0.0  0.448  6.069  40.0   5.7209   3.0  233.0
# 45   0.17142    0.0   6.91   0.0  0.448  5.682  33.8   5.1004   3.0  233.0
# 46   0.18836    0.0   6.91   0.0  0.448  5.786  33.3   5.1004   3.0  233.0
# 50   0.08873   21.0   5.64   0.0  0.439  5.963  45.7   6.8147   4.0  243.0
# 54   0.01360   75.0   4.00   0.0  0.410  5.888  47.6   7.3197   3.0  469.0
# 56   0.02055   85.0   0.74   0.0  0.410  6.383  35.7   9.1876   2.0  313.0
# ...

# %%
np.sum(casas_intervalo['TAX']) / len(casas_intervalo['TAX'])
# Out:
# 306.144578313253
